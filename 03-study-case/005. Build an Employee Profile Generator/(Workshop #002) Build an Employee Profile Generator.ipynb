# %% [markdown]
# # Python Certification freeCodeCamp
# ## Chapter: Python Basics
# ### Sub-Chapter: Build an Employee Profile Generator (Workshop)

# %% [markdown]
# After finishing the previous "Introduction to Strings" subchapter, in this 18-part workshop I create an Employee Profile Generator as the implementation of the theory.

# %% [markdown]
# ## 1. Step 1
# Create a variable first_name which stores the string John and a variable last_name which stores the string Doe. Then print first_name and last_name.

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)
# Out:
# John
# Doe

# %% [markdown]
# ## 2. Step 2
# Create a variable full_name by concatenating first_name and last_name. Then print full_name.

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)
full_name = first_name + last_name
print(full_name)
# Out:
# John
# Doe
# JohnDoe

# %% [markdown]
# ## 3. Step 3
# Update my full_name variable so it concatenates the first_name variable, a space (' '), and the last_name variable, in that order, using the + operator.

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)
full_name = first_name + ' ' + last_name
print(full_name)
# Out:
# John
# Doe
# John Doe

# %% [markdown]
# ## 4. Step 4
# Create a variable address to store the employee's address. Assign it the string 123 Main Street, and finally print address.

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)
full_name = first_name + ' ' + last_name
print(full_name)
address = '123 Main Street'
print(address)
# Out:
# John
# Doe
# John Doe
# 123 Main Street

# %% [markdown]
# ## 5. Step 5
# Add the apartment number where the employee lives. Use the += operator to add the string ', Apartment 4B' to my address variable.

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)
full_name = first_name + ' ' + last_name
print(full_name)
address = '123 Main Street'  
address += ', Apartment 4B'
print(address)
# Out:
# John
# Doe
# John Doe
# 123 Main Street, Apartment 4B

# %% [markdown]
# ## 6. Step 6
# Remove all the print() statements from my code because the outputs are too overcrowded.

# %%
first_name = 'John'  
last_name = 'Doe'  
full_name = first_name + ' ' + last_name  
address = '123 Main Street'  
address += ', Apartment 4B'

# %% [markdown]
# ## 7. Step 7
# Create a variable named employee_age and assign it the integer 28.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28

# %% [markdown]
# ## 8. Step 8
# Create a variable employee_info and assign it the result of concatenating, using the + operator:
# 1. the full_name variable.
# 2. a string consisting of the characters is preceded and followed by a space.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is '

# %% [markdown]
# ## 9. Step 9
# Update the employee_info assignment to also concatenate employee_age at the end, using the + operator.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + employee_age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       3 full_name = first_name + ' ' + last_name
#       4 address = '123 Main Street'
#       5 address += ', Apartment 4B'
#       6 employee_age = 28
# ----> 7 employee_info = full_name + ' is ' + employee_age
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Python raised a TypeError: can only concatenate str (not "int") to str. This happens because Python does not allow me to concatenate text (strings) and numbers (integers) directly.

# %% [markdown]
# ## 10. Step 10
# I must fix the error, therefore I update my employee_info assignment to convert employee_age to a string using str(employee_age).

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age)

# %% [markdown]
# ## 11. Step 11
# 1. Complete the sentence by updating the employee_info assignment to also concatenate the string  ' years old' at the end, using the + operator.
# 2. Include a space at the beginning of my string.
# 3. Finally, print employee_info.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
# Out:
# John Doe is 28 years old

# %% [markdown]
# ## 12. Step 12
# 1. I must convert any numeric variable to a string before concatenating it with other text.
# 2. Create a variable named experience_years and assign it the integer 5
# 3. Create a variable experience_info. Assign it a string formed by concatenating 'Experience: ', the experience_years variable (converted to a string), and ' years', using the + operator.
# 4. Print the result to the terminal.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)

experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
# Out:
# John Doe is 28 years old
# Experience: 5 years

# %% [markdown]
# ## 13. Step 13
# Create a variable employee_card and assign it an f-string that displays Employee: followed by a space and the value of the full_name variable.

# %% [markdown]
# Concatenating many strings using + and converting numbers using str() can get messy and hard to read.
# That's why Python 3.6 introduced f-strings f'{}' to solve this

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
employee_card = f'Employee: {full_name}'
# Out:
# John Doe is 28 years old
# Experience: 5 years

# %% [markdown]
# ## 14. Step 14
# Add more information to employee_card to include the employee's age. The final string should look like this: Employee: [name] | Age: [age] with [name] replaced with the employee's name, and [age] replaced with the employee's age.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
employee_card = f'Employee: {full_name} | Age: {employee_age}'

# %% [markdown]
# ## 15. Step 15
# It's time to add the final details to the card:

# %% [markdown]
# 1. Create a variable named position with the value of the string Data Analyst and a variable named salary with the value of the integer 75000.
# 2. Update my employee_card f-string to include the position and salary. It should follow this exact format: Employee: [full_name] | Age: [employee_age] | Position: [position] | Salary: $[salary]. Replace the placeholders with the corresponding variables.
# 3. Print employee_card to see the result.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
position = 'Data Analyst'
salary = 75000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)
# Out:
# John Doe is 28 years old
# Experience: 5 years
# Employee: John Doe | Age: 28 | Position: Data Analyst | Salary: $75000

# %% [markdown]
# ## 16. Step 16
# 1. Define employee_code as 'DEV-2026-JD-001'.
# 2. Create a variable department and assign it the slice of employee_code from index 0 to 3.
# 3. Print department to the terminal.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
position = 'Data Analyst'
salary = 75000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)

employee_code = 'DEV-2026-JD-001'
department = employee_code[0:3]
print(department)
# Out:
# John Doe is 28 years old
# Experience: 5 years
# Employee: John Doe | Age: 28 | Position: Data Analyst | Salary: $75000
# DEV

# %% [markdown]
# ## 17. Step 17
# 1. Create a variable year_code and assign it the slice of employee_code from index 4 to 8. This will extract 2026.
# 2. Create a variable initials and assign it the slice of employee_code from index 9 to 11. This will extract JD.
# 3. Print both variables to the terminal.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
position = 'Data Analyst'
salary = 75000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)
employee_code = 'DEV-2026-JD-001'
department = employee_code[0:3]
print(department) 
year_code = employee_code[4:8]
initials = employee_code[9:11]
print(year_code)
print(initials)
# Out:
# John Doe is 28 years old
# Experience: 5 years
# Employee: John Doe | Age: 28 | Position: Data Analyst | Salary: $75000
# DEV
# 2026
# JD

# %% [markdown]
# ## 18. Step 18
# 1. Create a variable named last_three.
# 2. Use negative indexing to extract the last three characters from employee_code (which represent the ID number).
# 3. Print last_three to the terminal.

# %%
first_name = 'John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
address = '123 Main Street'
address += ', Apartment 4B'
employee_age = 28
employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)
experience_years = 5
experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)
position = 'Data Analyst'
salary = 75000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)
employee_code = 'DEV-2026-JD-001'
department = employee_code[0:3]
print(department)
year_code = employee_code[4:8]
print(year_code)
initials = employee_code[9:11]
print(initials)
last_three = employee_code[-3:]
print(last_three)
# Out:
# John Doe is 28 years old
# Experience: 5 years
# Employee: John Doe | Age: 28 | Position: Data Analyst | Salary: $75000
# DEV
# 2026
# JD
# 001

# %% [markdown]
# The employee card workshop is complete.

# %% [markdown]
# # What's Next?
# I'll continue with the new Subchapter "Numbers and Mathematical Operations". You can check it here: https://github.com/anastasyapratiwi/python-playground/tree/main/01-preparation/4.%20Python%20Basics%20-%20freeCodeCamp/03.%20Numbers%20and%20Mathematical%20Operations
