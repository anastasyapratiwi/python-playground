# %% [markdown]
# # Python Certification - freeCodeCamp
# ## Chapter: Python Basics
# ## Sub-Chapter: Build a Report Card Printer
# I will practice Python data types by creating and printing data for a simple report card in this 10-part workshop.

# %% [markdown]
# # A. Create a variable called name and assign it the string Alice

# %%
name = "Alice"

# %% [markdown]
# Important: Python uses indentation (the spaces at the beginning of a line) to organize code. Adding extra spaces will cause an IndentationError and prevent your code from running.

# %% [markdown]
# # B. Print the value of a variable using the print() function

# %%
name = 'Alice'
print(name) # Output: Alice
# Out:
# Alice

# %% [markdown]
# # C. Check the type of a value

# %%
name = 'Alice'
print(name)
print(type(name)) # Output: <class 'str'>
# Out:
# Alice
# <class 'str'>

# %% [markdown]
# # D. Add the student's enrollment status using Boolean

# %%
name = 'Alice'
print(name)
print(type(name))

is_student = True
# Out:
# Alice
# <class 'str'>

# %% [markdown]
# # E. Print both enrollment status and its data type

# %%
name = 'Alice'
print(name)
print(type(name))

is_student = True
print(is_student, type(is_student))
# Out:
# Alice
# <class 'str'>
# True <class 'bool'>

# %% [markdown]
# # F. Make sure the same format for the student's name
# 1. I remove the earlier output of the name variable.
# 2. I write the code to print both name and its type(name) on the same line.

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))
# Out:
# Alice <class 'str'>
# True <class 'bool'>

# %% [markdown]
# # G. Add the student's age to the report card data

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>

# %% [markdown]
# # H. Add the student's score
# Although both age and score are numbers, they may not be the same kind. So I check if the score is also an integer.

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score,int))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# False

# %% [markdown]
# # I. Check if the score's data type is a float
# Turns out the score's data type is not an integer. So I check if it's a float.

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, float))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# True

# %% [markdown]
# # J. Complete the report card
# 1. The output is True, confirming that score is a float
# 2. I write the code to print both score and its type(name) on the same line.

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, float))
print(score, type(score))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# True
# 80.5 <class 'float'>

# %% [markdown]
# # It's Done!

# %% [markdown]
# # What's Next?
# Time to go back to the theory about strings! You can check my progress on this repo with the path: 01-preparation/4. Python Basics - freeCodeCamp (https://github.com/anastasyapratiwi/python-playground/tree/main/01-preparation/4.%20Python%20Basics%20-%20freeCodeCamp)
