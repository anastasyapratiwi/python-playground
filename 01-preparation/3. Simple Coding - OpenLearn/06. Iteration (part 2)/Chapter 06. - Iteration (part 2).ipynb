# %% [markdown]
# # Simple Coding - OpenLearn
# ## Chapter 06. Iteration (part 2)

# %% [markdown]
# Instructor:
# Michel Wermelinger |
# Faculty of Mathematics, Computing and Technology |
# Open University

# %% [markdown]
# This chapter is about a new iteration: an infinite loop that keeps asking until the user types ‘stop’

# %% [markdown]
# ####  The ‘while condition: block’ instruction

# %% [markdown]
#  Keeps executing the block while the condition is true. In this case the condition is always True (note the initial uppercase), which leads to an infinite loop.

# %% [markdown]
# #### Break instruction

# %% [markdown]
# Doing forever the same thing can get a bit tedious, that's why there's a break instruction. At that point the computer starts executing whatever code follows the loop.

# %% [markdown]
# #### The float function

# %% [markdown]
# float() is used because food and drink prices may be in pence or cents in some countries, so I have to convert the user’s input to a decimal number.

# %% [markdown]
# ### Test the code below: provide the same values as before (4.35, 2, 19.95, 22.70 and 5), followed by stop, and check the sum is at the end 54.

# %%
expenses = 0
while True:
  answer = input("Price of ordered item?")
  if answer == "stop":
    break
  else:
    price = float(answer)
    expenses = expenses + price
print("Total of orders:"), expenses
# Out:
# Total of orders:
# (None, 54.0)

# %% [markdown]
# ### Activity 9
# Put a complete program together, that starts as above, then asks the user for the number of people in the group, computes the tip and the VAT (20% on the expenses) and finally prints the total bill.

# %%
prices = []  # Create an empty list to store all the item prices

# Step 1: Input all the prices first
while True:
    answer = input("Price of ordered item? (or type 'stop'): ")
    if answer.lower() == "stop":
        break
    
    price = float(answer)
    prices.append(price)  # Add the price to our list

# Check if any items were actually ordered before moving on
if len(prices) > 0:
    # Step 2: Calculate the subtotal of all food items
    subtotal = sum(prices)
    
    # Step 3: Input the number of people later
    answer = input("How many people? ")
    people = int(answer)
    
    # Step 4: Determine the tip percentage based on total guests
    if people >= 15:
        percentage = 0.15
    elif people > 6:
        percentage = 0.10
    else:
        percentage = 0
        
    # Step 5: Calculate final tax and tips based on the entire meal
    tip = subtotal * percentage
    vat = subtotal * 0.20
    total_expenses = subtotal + tip + vat

    # Display the final bill breakdown
    print(f"\n--- Final Bill ---")
    print(f"Subtotal:       {subtotal:.2f}")
    print(f"Tip ({percentage*100:.0f}%):     {tip:.2f}")
    print(f"VAT (20%):      {vat:.2f}")
    print(f"Total Bill:     {total_expenses:.2f}")
else:
    print("No items were entered.")
# Out:
# --- Final Bill ---
# Subtotal:       54.00
# Tip (15%):     8.10
# VAT (20%):      10.80
# Total Bill:     72.90

# %% [markdown]
# #### "Cheat Sheet" of Common Patterns
# 1. The "Collect Until Stop" Pattern: (The while True: loop with an input() and a break).
# 2. The "Accumulator" Pattern: (Creating an empty list or setting a variable to 0, then adding to it inside a loop).
# 3. The "Decision Matrix" Pattern: (Using if / elif / else to pick a percentage).

# %% [markdown]
# ## 6.1 The oldest algorithm
# Euclid’s algorithm, used to find the greatest common divisor of two integers greater than zero, i.e. the greatest number that divides both without any remainder. For example, the greatest common divisor of 3 and 7 is 1, and of 21 and 49 is 7. This is needed to simplify fractions, for example. Explaining the maths that make the algorithm work is beyond the scope of this material.

# %% [markdown]
# ### Activity 10
# Translate the algorithm below to Python. One instruction was already translated for you. Don’t forget to test your code.

# %%
# Euclid's greatest common divisor algorithm

# ask user for an integer greater than zero
# store it in n
n = int(input("Enter an integer greater than zero for n: "))
m = int(input("Enter an integer greater than zero for m: "))

# while n and m are different:
while n != m:
  if n > m:
    n = n - m
  else:
    m = m - n
print("Their greatest common divisor is"), n
# Out:
# Their greatest common divisor is
# (None, 2)

# %%
# ask user for an integer greater than zero
# store it in m
m = int(input("Enter an integer greater than zero for m: "))
n = int(input("Enter an integer greater than zero for n: "))

# while n and m are different:
while n != m:
  if m > n:
    m = m - n
  else:
    n = n - m
print("Their greatest common divisor is"), m
# Out:
# Their greatest common divisor is
# (None, 1)

# %% [markdown]
# Note that for the loop to end, the condition must become false, i.e. both variables n and m have the same value. Therefore it doesn’t matter which one you print.

# %% [markdown]
# # What I've Learned (Again) from this Introductory Course about Coding:
# This is the first coding course I took taught entirely in English. My native language is Indonesian.

# %% [markdown]
# ## 1. The fundamental building blocks that almost every programming language provides:
# 1. variables and assignment (=) to store and update data
# 2. arithmetic operators (+, -, *)
# 3. simple data types (strings and numbers, both integers and floating point)
# 4. data structures (lists)
# 5. sequence (one instruction per line)
# 6. iteration (for and while loops)
# 7. selection (if-else and if-elif-elif-...-else),
# 8. comparisons (>, <, ==, !=, >=, <=)
# 9. functions (len and sum for lists, int and float to convert strings to numbers)
# 10. input from the keyboard (input function)
# 11. output to the screen (print instruction)

# %% [markdown]
# ## 2. Programming languages have to be automatically understood by a machine
# The syntax and grammar are very strict than English and other natural languages. Any spelling mistake, like writing flat instead of float or forgetting punctuation like commas and colons, or using the wrong data type, leads to an error. And I've been experiencing errors including crashing out my VS Code due to this.

# %% [markdown]
# ## 3. Programming involves writing clear and understandable code
# Using comments and plain English names for variables and functions to make it easier to change later, and testing it thoroughly. The more challenging the subject is, the more I find myself to use the comments feature (mostly in Python files and now finally in Jupyter Notebooks). The first I did when I knew R, I searched up how to write a comment in a single and multiple lines. I hope this healthy habit continues if I ever learn new programming language in the future!

# %% [markdown]
# ## 4. Learning to program forces me to think clearly and rigorously when solving a problem
# The solution has to be described in very small and precise steps that even a machine can understand. Python makes it easy to write the code once we come up with a sufficiently detailed algorithm, but the thinking (still) has to be done by myself. This also helps me channel my overthinking tendency into something more practical and led me to discover my problem-solving side.

# %% [markdown]
# ## 5. Only practice makes perfect
# As a non-IT grad, I found that learning any skills including Python programming can only be done through practice. There are still so much for me to learn. Thank you to Mr. Welminger and OpenLearn (part of Open University) who hope this course inspired me to learn more Python and to share my creations with friends and family. I can now say that I'm not only writing in Indonesian and English, but also in code!

# %% [markdown]
# For my Statement of participation from OpenLearn (part of Open University), check README.md.
# Thank you.
