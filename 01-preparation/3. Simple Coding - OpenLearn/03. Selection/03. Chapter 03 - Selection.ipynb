# %% [markdown]
# # Simple Coding - OpenLearn
# ## Chapter 03. Selection

# %% [markdown]
# Instructor:
# Michel Wermelinger |
# Faculty of Mathematics, Computing and Technology |
# Open University

# %%
# -- 1. Developing software for a restaurant --
expenses = 54
people = 7
if people > 6:
    percentage = 0.10
else:
    percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 59.4)

# %% [markdown]
# ### Activity 3
# Change the number of people to 6 and confirm the bill is just the expenses in that case.

# %%
expenses = 54
people = 6
if people > 6:
  percentage = 0.10
else:
  percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 54)

# %% [markdown]
# ### Why the results are different?
# 1. The borderlines where the tip percentage changes are 6 and 7 people, so I have to test this to prove the "if - else" formula
# 2. Above 6 people (starting from 7 people), the tip is 10%. Meanwhile, 6 people AND less don't have to tip (0%).

# %% [markdown]
# ## 3.1 And now for something not completely different

# %% [markdown]
# ### Activity 4
# Keep the rate at 10% but change the way the tip is computed: if there are more than 6 people, let the tip be the expenses times the rate, otherwise let the tip be zero. Change the code accordingly

# %%
# a. For more than 6 people
expenses = 54
people = 9
if people > 6:
  rate = 0.10
else:
  rate = 0

tip = expenses * rate
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 59.4)

# %%
# b. For 6 people
expenses = 54
people = 6
if people > 6:
  rate = 0.10
else:
  rate = 0

tip = expenses * rate
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 54)

# %%
#  c. For less than 6 people
expenses = 54
people = 2
if people > 6:
  rate = 0.10
else:
  rate = 0

tip = expenses * rate
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 54)

# %% [markdown]
# ### Addition: Tip of 15% for groups of at least 15 people
# ### Activity 5
# Test the code with the four borderline cases: 6, 7, 14 and 15 people.

# %%
# a. For 6 people
expenses = 54
people = 6
if people >= 15:
  percentage = 0.15
elif people > 6:
    percentage = 0.10
else:
  percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 54)

# %%
# b. For 7 people
expenses = 54
people = 7
if people >= 15:
  percentage = 0.15
elif people > 6:
    percentage = 0.10
else:
  percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 59.4)

# %%
# c. For 14 people
expenses = 54
people = 14
if people >= 15:
  percentage = 0.15
elif people > 6:
    percentage = 0.10
else:
  percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 59.4)

# %%
# d. For 15 people: 
expenses = 54
people = 15
if people >= 15:
  percentage = 0.15
elif people > 6:
    percentage = 0.10
else:
  percentage = 0

tip = expenses * percentage
bill = expenses + tip
print("Total bill:"), bill
# Out:
# Total bill:
# (None, 62.1)

# %% [markdown]
# ### Results Breakdown
# 1. The customer pay less if they come in smaller groups.
# 2. The cheapest paying group is customers with 6 people or less. They only pay the expenses. No tip required (0%).
# 3. The restaurant can make more money if the customers come in 15 people and more in a group, since the tip is the biggest (15%).
# 4. The restaurant can only start receiving tip (10%) when the group of customers come in 7-14 people.

# %% [markdown]
# ### Activity 6
# Explain why the following code is wrong. Hint: repeat the tests and see what happens. That’s what tests are for.

# %%
expenses = 54
people = 2
if people > 6:
  percentage = 0.10
elif people >= 15:
  percentage = 0.15
else:
  percentage = 0
tip = expenses * percentage
bill = expenses + tip
print "Total bill:", bill
# Out:
#   Cell In[14], line 11
#     print "Total bill:", bill
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# ### Explanation of the code error
# 1. It doesn't have parantheses, causing error. The code should be: print("Total bill"), bill
# 2. The coder should've written the condition of if with equal and more than 15 people first, followed by elif with the condition of more than 6 people. Because computer always execute starting with the first condition. If not changed, the computation will mistakenly charges 10% tip to customers that come in groups in 15 people and more, when they're supposed to add the 15% tip as part of their bill.
# 3. The people input is too little. It didn't fit the borderline test. The coder should test the if-elif-else logic with the numbers = 6, 7, 14, 15.

# %% [markdown]
# ## Tips from Mr. Wermelinger
# 1. Usually there are many ways to solve the same problem
# 2. The order in which we write the conditions is important, because the computer checks them from top to bottom and executes only one block, for the first condition that is true. The else block has no condition, so it’s a ‘catch all’ in case no condition is true.
