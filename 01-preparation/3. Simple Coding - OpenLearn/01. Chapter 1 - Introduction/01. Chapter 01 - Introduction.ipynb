# %% [markdown]
# # Simple Coding - OpenLearn
# ## Chapter 01. Introduction

# %%
# Example 1
result = 3 + 7
print("The sum of 3 and 7 is:"), result
# Out:
# Error: Failed to create kernel session on nbctl: nbctl vsessions unavailable: request to http://localhost:8888/api/internal/vsessions failed, reason:
#
#     at doEnsureKernel (c:\Users\Asus\.vscode\extensions\snowflake.snowflake-vsc-1.38.0-win32-x64\extension.js:1:5662625)
#
#     at processTicksAndRejections (node:internal/process/task_queues:104:5)
#
#     at ensureKernel (c:\Users\Asus\.vscode\extensions\snowflake.snowflake-vsc-1.38.0-win32-x64\extension.js:1:5663867)
#
#     at Object.<anonymous> (c:\Users\Asus\.vscode\extensions\snowflake.snowflake-vsc-1.38.0-win32-x64\extension.js:1:5677124)
#
#     at _h.$executeCells (file:///d:/Program%20Files/Microsoft%20VS%20Code/110a328ea5/resources/app/out/vs/workbench/api/node/extensionHostProcess.js:674:28892)

# %%
# Tweaking 1
result = 3 + 2
print("The sum of 3 and 2 is:"), result

# %%
# Example 2
expenses = 54
people = 7
if people > 6:
    percentage = 0.10
else:
    percentage = 0
tip = expenses * percentage
bill = expenses * tip
print("Total Bill:"), bill
