# %% [markdown]
# # Python Certification freeCodeCamp
# ## Chapter: Python Basics
# ### Subchapter: Booleans and Conditionals

# %% [markdown]
# # A. How Do Conditional Statements and Logical Operators Work?

# %% [markdown]
# Conditional statements, or conditionals, let me control the flow of my program based on whether certain conditions are true or false.

# %% [markdown]
# ## 1. Comparison operators
# Comparison operators are operators that let me compare two or more values, and return a boolean value.

# %% [markdown]
# ### a. Equal (==)
# Checks if two values are equal

# %% [markdown]
# ### b. Not equal (!=)
# Checks if two values are not equal

# %% [markdown]
# ### c. Greater than (>)
# Checks if the value on the left is greater than the value on the right

# %% [markdown]
# ### d. Less than (<)
# Checks if the value on the left is less than the value on the right

# %% [markdown]
# ### e. Greater than or equal (>=)
# Checks if the value on the left is greater than or equal to the value on the right

# %% [markdown]
# ### f. Less than or equal (<=)
# Checks if the value on the left is less than or equal to the value on the right

# %% [markdown]
# ### Example code that evaluate to True or False

# %%
print(3 > 4) # False
print(3 < 4) # True
print(3 == 4) # False
print(4 == 4) # True
print(3 != 4) # True
print(3 >= 4) # False
print(3 <= 4) # True
# Out:
# False
# True
# False
# True
# True
# False
# True

# %% [markdown]
# ## 2. Basic conditionals (if statement)

# %% [markdown]
# ### a. Basic syntax

# %%
"""
if condition:
  pass # Code to execute if condition is True
"""
# Out:
# '\nif condition:\n  pass # Code to execute if condition is True\n'

# %% [markdown]
# Note:
# 1. if statements start with the if keyword.
# 2. condition is an expression that evaluates to True or False, followed by a colon (:).
# 3. The body of the if statement constitutes a code block, which is a group of statements that belong together. Spaces at the beginning of a line are called indentation, it determines which statements belong to a code block.

# %% [markdown]
# ### b. When the condition is true

# %%
age = 18

if age >= 18:
  print('You are an adult') # You are an adult
# Out:
# You are an adult

# %% [markdown]
# ### c. When the indentation isn't right

# %%
age = 18

if age >= 18:
print('You are an adult') # IndentationError: expected an indented block after 'if' statement on line 3
# Out:
#   Cell In[45], line 4
#     print('You are an adult') # IndentationError: expected an indented block after 'if' statement on line 3
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %% [markdown]
# ### d. When the condition is false

# %%
age = 12

if age >= 18:
  print('You are an adult') # Nothing shows up in the terminal

# %% [markdown]
# ## 3. if ... else statement
# The else clause runs when the if condition is false.

# %% [markdown]
# ### a. Basic syntax

# %%
"""
if condition:
   pass # Code to execute if condition is True
else:
   pass # Code to execute if condition is False
"""
# Out:
# '\nif condition:\n   pass # Code to execute if condition is True\nelse:\n   pass # Code to execute if condition is False\n'

# %% [markdown]
# ### b. Example code

# %%
age = 12

if age >= 18:
  print('You are an adult')
else:
  print('You are not an adult yet') # You are not an adult yet
# Out:
# You are not an adult yet

# %% [markdown]
# ### c. Don't place any staments between (SyntaxError)

# %%
age = 12

if age >= 18:
  print('You are an adult')
print('Almost there!')
else: # SyntaxError: invalid syntax
  print('You are not an adult yet') # You are not an adult yet
# Out:
#   Cell In[14], line 6
#     else: # SyntaxError: invalid syntax
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4. elif clause for multiple conditions
# Extension of the if statement with the elif (else if) clause

# %% [markdown]
# ### a. Basic syntax

# %%
"""
if condition1:
   pass # Code to execute if condition1 is True
elif condition2:
   pass # Code to execute if condition1 is False and condition2 is True
else:
   pass # Code to execute if all conditions are False
"""
# Out:
# '\nif condition1:\n   pass # Code to execute if condition1 is True\nelif condition2:\n   pass # Code to execute if condition1 is False and condition2 is True\nelse:\n   pass # Code to execute if all conditions are False\n'

# %% [markdown]
# ### b. Example code

# %%
age = 12

if age >= 18:
  print('You are an adult')
elif age >= 13:
  print('You are a teenager')
else:
  print('You are a child') # You are a child
# Out:
# You are a child

# %% [markdown]
# ### c. Use elif clauses as many as I want

# %%
age = 2
if age >= 65:
  print('You are a senior citizen')
elif age >= 30:
  print('You are an adult in your prime')
elif age >= 18:
  print('You are a young adult')
elif age >= 13:
  print('You are a teenager')
elif age >= 3:
  print('You are a young child')
else:
  print('You are a toddler or an infant') # You are a toddler or an infant
# Out:
# You are a toddler or an infant

# %% [markdown]
# Now I can continue writing programs that make decisions based on logic and input. Whether I'm comparing values or branching through multiple conditions, these tools help me to write flexible and responsive code.

# %% [markdown]
# # B. What Are Truthy and Falsy Values, and How Do Boolean Operators and Short-Circuiting Work?

# %% [markdown]
# ## 1. Nested conditionals statements
# to compare multiple values at once

# %% [markdown]
# ### Example code:

# %%
is_citizen = True
age = 25

if is_citizen:
  if age >= 18:
    print('You are eligible to vote') # You are eligible to vote
  else:
    print('You are not eligible to vote')
# Out:
# You are eligible to vote

# %% [markdown]
# The code first check if is_citizen is True. If so, it will then go to the nested if statement and check if age is greater than or equal to 18. Since age is greater than or equal to 18, the message printed to the terminal will be "You are eligible to vote". If is_citizen were False, then the message printed to the terminal would have been "You are not eligible to vote".

# %% [markdown]
# ## 2. Truthy and Falsy Values
# 1. Every value has an inherent boolean value (True or False).
# 2. Many values are considered truthy, they evaluate to True.
# 3. Others are falsy, they evaluate to False.

# %% [markdown]
# ### a. Falsy Values examples
# 1. False
# 2. Integer 0
# 3. Float 0.0
# 4. Empty strings ""

# %% [markdown]
# ### b. Truthy Values examples
# 1. Non-zero numbers
# 2. Non-empty strings

# %% [markdown]
# ### c. Example code using bool()
# It converts a value to its boolean equivalent and returns True for truthy values and False for falsy values.

# %%
print(bool(False)) # False
print(bool(0)) # False
print(bool('')) # False

print(bool(True)) # True
print(bool(1)) # True
print(bool('Hello')) # True
# Out:
# False
# False
# False
# True
# True
# True

# %% [markdown]
# ## 3. Boolean Operators/Logical Operators
# 1. They combine multiple expressions to create more complex decision-making logic in my code
# 2. The operators are: "and", "or", and "not"

# %% [markdown]
# ### a. The "and" operator
# 1. Both operands must be truthy for an expression to result in a truthy value.
# 2. Known as a short-circuit operator. It checks values from left to right and stops as soon as it determines the final result.

# %% [markdown]
# #### i. Example code

# %%
is_citizen = True
age = 25

print(is_citizen and age) # 25
# Out:
# 25

# %% [markdown]
# The number 25 is printed to the terminal because the "and" operator evaluated the second operand if the first operand is True.

# %% [markdown]
# #### ii. "and" operator in if...else statement
# to check if multiple conditions are met.

# %%
is_citizen = True
age = 25

if is_citizen and age >= 18:
  print('You are eligible to vote') # You are eligible to vote
else:
  print('You are not eligible to vote')
# Out:
# You are eligible to vote

# %% [markdown]
# Since both operands of the "and" operator are truthy, the condition is_citizen and age >= 18 evaluates to True, and the print call in the if block is executed.

# %% [markdown]
# ### b. The "or" operator
# 1. Results in a truthy value if at least one operand is truthy.
# 2. Also known as a short-circuit operator.

# %% [markdown]
# #### i. Example code

# %%
age = 19
is_employed = False

print(age or is_employed) # 19
# Out:
# 19

# %% [markdown]
# It printed the number 19 because the first operand age is truthy.

# %% [markdown]
# #### ii. or operator in a conditional
# to check if one or more expressions is True

# %%
age = 19
is_student = True

if age < 18 or is_student:
  print('You are eligible for a student discount') # You are eligible for a student discount
else:
  print('You are not eligible for a student discount')
# Out:
# You are eligible for a student discount

# %% [markdown]
# Since at least one condition is true, the entire or expression evaluates to True, and the discount message in the if block is printed.

# %% [markdown]
# ### c. The "not" operator
# 1. It converts truthy values to False and falsy values to True.
# 2. not always returns True or False

# %% [markdown]
# #### i. Example code

# %%
print(not '') # True, because empty string is falsy
print(not 'Hello') # False, because non-empty string is truthy
print(not 0) # True, because 0 is falsy
print(not 1) # False, because 1 is truthy
print(not False) # True, because False is falsy
print(not True) # False, because True is truthy
# Out:
# True
# False
# True
# False
# True
# False

# %% [markdown]
# #### ii. to check if something is not True or False in conditionals

# %%
is_admin = False

if not is_admin:
  print('Access denied for non-administrators.') # Access denied for non-administrators.
else:
  print('Welcome, Administrator!')
# Out:
# Access denied for non-administrators.

# %% [markdown]
# Now I can write more readable conditional logic.

# %% [markdown]
# # What's Next?
# The next challenge is to build a movie ticket booking calculator. The 21-part workshop will be the longest I've ever taken in this course. You can check my progress here: https://github.com/anastasyapratiwi/python-playground/tree/main/03-study-case/007.%20Build%20a%20Movie%20Ticket%20Booking%20Calculator
